# %%
pip install simpletransformers
# Out:
# Collecting simpletransformers
#   Downloading simpletransformers-0.61.13-py3-none-any.whl (221 kB)
#      |████████████████████████████████| 221 kB 8.1 MB/s
# Collecting wandb>=0.10.32
#   Downloading wandb-0.12.1-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 52.7 MB/s
# Collecting tensorboardx
#   Downloading tensorboardX-2.4-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 37.7 MB/s
# Collecting transformers>=4.2.0
#   Downloading transformers-4.10.0-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 51.6 MB/s
# Collecting datasets
#   Downloading datasets-1.11.0-py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 37.0 MB/s
# Collecting streamlit
#   Downloading streamlit-0.87.0-py2.py3-none-any.whl (8.0 MB)
#      |████████████████████████████████| 8.0 MB 12.7 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 56.9 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.19.5)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (4.62.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2.23.0)
# Collecting tokenizers
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 46.2 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2019.12.20)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (0.22.2.post1)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.6 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers>=4.2.0->simpletransformers) (21.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 45.4 MB/s
# Collecting huggingface-hub>=0.0.12
#   Downloading huggingface_hub-0.0.16-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.4 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=4.2.0->simpletransformers) (4.6.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.2.0->simpletransformers) (3.0.12)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 64.7 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.12->transformers>=4.2.0->simpletransformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers>=4.2.0->simpletransformers) (2.4.7)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (1.15.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.18-py3-none-any.whl (170 kB)
#      |████████████████████████████████| 170 kB 58.0 MB/s
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.3.1-py2.py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 62.5 MB/s
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (7.1.2)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (2.8.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (5.4.8)
# Collecting configparser>=3.8.1
#   Downloading configparser-5.0.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (3.17.3)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (2.3)
# Collecting subprocess32>=3.5.3
#   Downloading subprocess32-3.5.4.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 8.6 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.1 MB/s
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2.10)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.70.12.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.3.4)
# Collecting fsspec>=2021.05.0
#   Downloading fsspec-2021.8.1-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 52.2 MB/s
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 65.0 MB/s
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (3.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=4.2.0->simpletransformers) (3.5.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->simpletransformers) (2018.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.2.0->simpletransformers) (1.0.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (7.1.2)
# Collecting watchdog
#   Downloading watchdog-2.1.5-py3-none-manylinux2014_x86_64.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.7 MB/s
# Collecting base58
#   Downloading base58-2.1.0-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.1.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.2.2)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.8.1)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 61.7 MB/s
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.0-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 22.5 MB/s
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (1.5.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (21.2.0)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (5.1.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (2.11.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.11.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (2.6.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (7.6.3)
# Collecting ipykernel>=5.1.2
#   Downloading ipykernel-6.3.1-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 78.2 MB/s
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (5.0.5)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.3.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.0.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Collecting ipython<8.0,>=7.23.1
#   Downloading ipython-7.27.0-py3-none-any.whl (787 kB)
#      |████████████████████████████████| 787 kB 72.6 MB/s
# Requirement already satisfied: argcomplete>=1.12.3 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.12.3)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.20-py3-none-any.whl (370 kB)
#      |████████████████████████████████| 370 kB 75.4 MB/s
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (2.6.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.18.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (57.4.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.8.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->altair>=3.2.0->streamlit->simpletransformers) (2.0.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (22.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.3.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.4.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.0.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.5.1)
# Building wheels for collected packages: subprocess32, pathtools, seqeval, blinker
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=7949c8486f021cab6ca87e5e4f80bda5c5df05bd608e87cf73bc31e680e3a70f
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=d3ca6163083a6e9262eb8dc09c7d9dacb0786f0f50ee5ec0f978a67fed48e4ce
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=24d7c99a87abc6c9af2eae9e098083d83959a764e675fbd2dcedeb93e536f1a6
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for blinker (setup.py) ... done
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=425d6a05099d621f3ade81510ff18d3e649be49dcdd2de7d0de85840349e4b63
#   Stored in directory: /root/.cache/pip/wheels/22/f5/18/df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
# Successfully built subprocess32 pathtools seqeval blinker
# Installing collected packages: prompt-toolkit, ipython, ipykernel, smmap, gitdb, xxhash, watchdog, validators, tokenizers, subprocess32, shortuuid, sentry-sdk, sacremoses, pyyaml, pydeck, pathtools, huggingface-hub, GitPython, fsspec, docker-pycreds, configparser, blinker, base58, wandb, transformers, tensorboardx, streamlit, seqeval, sentencepiece, datasets, simpletransformers
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Attempting uninstall: ipython
#     Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.20 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.3.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.27.0 which is incompatible.
# Successfully installed GitPython-3.1.18 base58-2.1.0 blinker-1.4 configparser-5.0.2 datasets-1.11.0 docker-pycreds-0.4.0 fsspec-2021.8.1 gitdb-4.0.7 huggingface-hub-0.0.16 ipykernel-6.3.1 ipython-7.27.0 pathtools-0.1.2 prompt-toolkit-3.0.20 pydeck-0.7.0 pyyaml-5.4.1 sacremoses-0.0.45 sentencepiece-0.1.96 sentry-sdk-1.3.1 seqeval-1.2.2 shortuuid-1.0.1 simpletransformers-0.61.13 smmap-4.0.0 streamlit-0.87.0 subprocess32-3.5.4 tensorboardx-2.4 tokenizers-0.10.3 transformers-4.10.0 validators-0.18.2 wandb-0.12.1 watchdog-2.1.5 xxhash-2.0.2

# %%
import math
import random
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px


import seaborn as sns
from datetime import datetime
import time

import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer


from simpletransformers.classification import ClassificationModel, ClassificationArgs
import torch
cuda_available = torch.cuda.is_available()


plt.style.use('classic')
# %matplotlib inline
sns.set()

from google.colab import drive
drive.mount('/gdrive')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Mounted at /gdrive

# %% [markdown]
# ### Functions

# %%
def filter_df(df, df_column, lower_bound=False, upper_bound=False):
    if lower_bound and upper_bound:
        if lower_bound <= upper_bound:
            mask = (df_column >= lower_bound) & (df_column <= upper_bound)
        else:
            mask = (df_column >= lower_bound) | (df_column <= upper_bound)
    elif lower_bound:
        mask = (df_column >= lower_bound)
    elif upper_bound:
        mask = (df_column <= upper_bound)
    else:
        return df
    return df.loc[mask]


def tweets_cleaner(text):

    text = ' '.join(text.split('.'))
    text = re.sub('\/',' ',text)
    text = text.strip('\'"')
    text = re.sub(r'@([^\s]+)',r'\1',text)
    text = re.sub(r'\\',' ',text)
    text = text.lower()
    text = re.sub('[\s]+', ' ', text)
    text = re.sub(r'#([^\s]+)', r'\1', text)
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))',' ',text)
    text = re.sub(r'((http)\S+)','',text)
    text = re.sub(r'\s+', ' ', re.sub('[^A-Za-z]', ' ', text.strip().lower())).strip()
    text = re.sub(r'\W+', ' ', text.strip().lower()).strip()

    return text

# %% [markdown]
# # 2019

# %% [markdown]
# ## Datasets

# %%
df_tweets_2019 = pd.read_csv("/gdrive/My Drive/TextAnalytics/datasets/df_tweets_2019.csv")

df_tweets_2019['date'] = pd.to_datetime(df_tweets_2019['date'])
df_tweets_2019 = df_tweets_2019.set_index(['date']).sort_index()

df_tweets_2019
# Out:
#                                                                   text
# date
# 2019-05-06 00:00:01              h long btc btc short btc btc ls vs vs
# 2019-05-06 00:00:01  current prices and changes in the last hour bt...
# 2019-05-06 00:00:02  binance btt btc npxs btc dent btc bcn btc hot btc
# 2019-05-06 00:00:03  btc eth etc bch xrp xem lsk mona bitcoin bitfl...
# 2019-05-06 00:00:05  total market cap btc btc dominance update time...
# ...                                                                ...
# 2019-09-26 23:59:39  bought lots of bags on sale over the past hour...
# 2019-09-26 23:59:53  here is my bitcoin prediction of tomorrow pred...
# 2019-09-26 23:59:55  pay me in bitcoin using my t co pmgta gg t co ...
# 2019-09-26 23:59:57  the future is open source stake amp earn rewar...
# 2019-09-27 00:00:00              h long btc btc short btc btc ls vs vs
#
# [2389238 rows x 1 columns]

# %% [markdown]
# ## Vader Sentiment

# %%
vader = SentimentIntensityAnalyzer()

# %%
df_tweets_2019["vader_polarity"] = df_tweets_2019["text"].apply(lambda text: vader.polarity_scores(str(text)).get('compound'))

# %%
def fromPolarity_toSentiment(polarity):
    if polarity>=0.7:
        return 1
    elif polarity<=-0.3:
        return -1
    else:
        return 0

df_tweets_2019["vader_sentiment"] = df_tweets_2019["vader_polarity"].apply(fromPolarity_toSentiment)

# %%
df_tweets_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2389238 entries, 2019-05-06 00:00:01 to 2019-09-27 00:00:00
# Data columns (total 3 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   text             object
#  1   vader_polarity   float64
#  2   vader_sentiment  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 72.9+ MB

# %%
df_tweets_2019
# Out:
#                                                                   text  ...  vader_sentiment
# date                                                                    ...
# 2019-05-06 00:00:01              h long btc btc short btc btc ls vs vs  ...                0
# 2019-05-06 00:00:01  current prices and changes in the last hour bt...  ...                0
# 2019-05-06 00:00:02  binance btt btc npxs btc dent btc bcn btc hot btc  ...                0
# 2019-05-06 00:00:03  btc eth etc bch xrp xem lsk mona bitcoin bitfl...  ...                0
# 2019-05-06 00:00:05  total market cap btc btc dominance update time...  ...                0
# ...                                                                ...  ...              ...
# 2019-09-26 23:59:39  bought lots of bags on sale over the past hour...  ...                0
# 2019-09-26 23:59:53  here is my bitcoin prediction of tomorrow pred...  ...                0
# 2019-09-26 23:59:55  pay me in bitcoin using my t co pmgta gg t co ...  ...                0
# 2019-09-26 23:59:57  the future is open source stake amp earn rewar...  ...                1
# 2019-09-27 00:00:00              h long btc btc short btc btc ls vs vs  ...                0
#
# [2389238 rows x 3 columns]

# %%
df_tweets_2019["vader_sentiment"].value_counts()
# Out:
#  0    1870236
#  1     273835
# -1     245167
# Name: vader_sentiment, dtype: int64

# %%
df_tweets_2019["vader_sentiment"].value_counts(normalize=True)
# Out:
#  0    0.782775
#  1    0.114612
# -1    0.102613
# Name: vader_sentiment, dtype: float64

# %%
df_tweets_2019["vader_sentiment"].value_counts() # con range [-1; -0.5], [-0.5; 0.5], [0.5, 1]
# Out:
#  0    1736076
#  1     520066
# -1     133096
# Name: vader_sentiment, dtype: int64

# %%
df_tweets_polarized_2019 = df_tweets_2019.loc[df_tweets_2019["vader_sentiment"] != 0]

# %%
df_tweets_polarized_2019
# Out:
#                                                                   text  ...  vader_sentiment
# date                                                                    ...
# 2019-05-06 02:25:41  wish token giveaway retweet and like this twee...  ...                1
# 2019-05-06 02:29:30  wish is a decentralized reward platform powere...  ...                1
# 2019-05-06 03:34:48  new tasks added to contest enter to win huge c...  ...                1
# 2019-05-06 05:29:29  achain congrats our community member artemiycr...  ...                1
# 2019-05-06 05:50:31  join on kingcuan our bot will automatically ma...  ...                1
# ...                                                                ...  ...              ...
# 2019-09-26 23:57:50  on september daps will make its long awaited t...  ...                1
# 2019-09-26 23:58:06  judge denies release of canadian man accused o...  ...               -1
# 2019-09-26 23:58:30  dutchsunset alexkjanssen alexcobb this message...  ...               -1
# 2019-09-26 23:58:46  pezosaso aaronlevi ltc apompliano changing the...  ...               -1
# 2019-09-26 23:59:57  the future is open source stake amp earn rewar...  ...                1
#
# [519002 rows x 3 columns]

# %%
df_tweets_polarized_2019["vader_sentiment"] = df_tweets_polarized_2019["vader_sentiment"].replace(-1, 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
del df_tweets_2019

# %%
df_tweets_polarized_2019.to_csv('/gdrive/My Drive/TextAnalytics/datasets/df_tweets_polarized_2019.csv')

# %% [markdown]
# ## Transformers Sentiment

# %%
# !pip install simpletransformers

# %%
df_tweets_polarized_2019 = pd.read_csv("/gdrive/My Drive/TextAnalytics/datasets/df_tweets_polarized_2019.csv")
#df_tweets_polarized_2019 = pd.read_csv(r"C:\Users\aine2\Downloads\df_tweets_polarized_2019.csv")

df_tweets_polarized_2019['date'] = pd.to_datetime(df_tweets_polarized_2019['date'])
df_tweets_polarized_2019 = df_tweets_polarized_2019.set_index(['date']).sort_index()

df_tweets_polarized_2019
# Out:
#                                                                   text  \
# date
# 2019-05-06 02:25:41  wish token giveaway retweet and like this twee...
# 2019-05-06 02:29:30  wish is a decentralized reward platform powere...
# 2019-05-06 03:34:48  new tasks added to contest enter to win huge c...
# 2019-05-06 05:29:29  achain congrats our community member artemiycr...
# 2019-05-06 05:50:31  join on kingcuan our bot will automatically ma...
# ...                                                                ...
# 2019-09-26 23:57:50  on september daps will make its long awaited t...
# 2019-09-26 23:58:06  judge denies release of canadian man accused o...
# 2019-09-26 23:58:30  dutchsunset alexkjanssen alexcobb this message...
# 2019-09-26 23:58:46  pezosaso aaronlevi ltc apompliano changing the...
# 2019-09-26 23:59:57  the future is open source stake amp earn rewar...
#
#                      vader_polarity  vader_sentiment
# date
# 2019-05-06 02:25:41          0.7351                1
# 2019-05-06 02:29:30          0.9451                1
# 2019-05-06 03:34:48          0.8442                1
# 2019-05-06 05:29:29          0.8625                1
# 2019-05-06 05:50:31          0.7506                1
# ...                             ...              ...
# 2019-09-26 23:57:50          0.7884                1
# 2019-09-26 23:58:06         -0.8316                0
# 2019-09-26 23:58:30         -0.4588                0
# 2019-09-26 23:58:46         -0.5994                0
# 2019-09-26 23:59:57          0.8176                1
#
# [519002 rows x 3 columns]

# %%
# https://simpletransformers.ai/docs/classification-data-formats/

df_train_transformers_2019 = df_tweets_polarized_2019[["text", "vader_sentiment"]].loc[df_tweets_polarized_2019.index <= "2019-09-01 00:00:00"].copy()

df_train_transformers_2019.columns = ["text", "labels"]

# %%
df_train_transformers_2019
# Out:
#                                                                   text  labels
# date
# 2019-05-06 02:25:41  wish token giveaway retweet and like this twee...       1
# 2019-05-06 02:29:30  wish is a decentralized reward platform powere...       1
# 2019-05-06 03:34:48  new tasks added to contest enter to win huge c...       1
# 2019-05-06 05:29:29  achain congrats our community member artemiycr...       1
# 2019-05-06 05:50:31  join on kingcuan our bot will automatically ma...       1
# ...                                                                ...     ...
# 2019-08-31 23:58:48  iam platform curated tweet report telegram tok...       0
# 2019-08-31 23:59:01  i m guessing leo will always hold due to reput...       0
# 2019-08-31 23:59:17  for if you transactpurposefully transactneedfu...       0
# 2019-08-31 23:59:43  i ve been using coinbase which makes it really...       1
# 2019-08-31 23:59:47  hourly price update usdt bsv bitcoin dead fork...       0
#
# [434566 rows x 2 columns]

# %%
df_test_transformers_2019 = df_tweets_polarized_2019[["text", "vader_sentiment"]].loc[df_tweets_polarized_2019.index > "2019-09-01 00:00:00"].copy()

df_test_transformers_2019.columns = ["text", "labels"]

# %%
df_test_transformers_2019
# Out:
#                                                                   text  labels
# date
# 2019-09-01 00:00:02  txs size kb stripped kb time reward btc fees b...       1
# 2019-09-01 00:00:02  binance margin trade bnb delta exchange upto x...       0
# 2019-09-01 00:00:02  you suffer but why bitcoin just hit time to re...       0
# 2019-09-01 00:00:03  join the signal premium sign up here t co npgo...       1
# 2019-09-01 00:00:26  bitcoin a very easy way to earn money do you w...       1
# ...                                                                ...     ...
# 2019-09-26 23:57:50  on september daps will make its long awaited t...       1
# 2019-09-26 23:58:06  judge denies release of canadian man accused o...       0
# 2019-09-26 23:58:30  dutchsunset alexkjanssen alexcobb this message...       0
# 2019-09-26 23:58:46  pezosaso aaronlevi ltc apompliano changing the...       0
# 2019-09-26 23:59:57  the future is open source stake amp earn rewar...       1
#
# [84436 rows x 2 columns]

# %%
df_validation_transformers_2019 = df_train_transformers_2019.loc[df_train_transformers_2019.index > "2019-08-21 00:00:00"].copy()

df_train_transformers_2019 = df_train_transformers_2019.loc[df_train_transformers_2019.index <= "2019-08-21 00:00:00"].copy()

# %%
df_train_transformers_2019
# Out:
#                                                                   text  labels
# date
# 2019-05-06 02:25:41  wish token giveaway retweet and like this twee...       1
# 2019-05-06 02:29:30  wish is a decentralized reward platform powere...       1
# 2019-05-06 03:34:48  new tasks added to contest enter to win huge c...       1
# 2019-05-06 05:29:29  achain congrats our community member artemiycr...       1
# 2019-05-06 05:50:31  join on kingcuan our bot will automatically ma...       1
# ...                                                                ...     ...
# 2019-08-20 23:59:02  t dd kanuuker homelessonmoon bitcoinerrorlog b...       0
# 2019-08-20 23:59:08  mohtasem bgiradji jesusxrp i m sorry huh you s...       0
# 2019-08-20 23:59:30  who is making big moves yes lit and ftm are do...       1
# 2019-08-20 23:59:35  people dont believe in local international wea...       1
# 2019-08-20 23:59:45  btc x made some adjustments over previous char...       0
#
# [399003 rows x 2 columns]

# %%
df_validation_transformers_2019
# Out:
#                                                                   text  labels
# date
# 2019-08-21 00:00:04  crypto h losers egt volume btc bcd volume btc ...       0
# 2019-08-21 00:00:05  btc top last h rvn st npxs st gxc st xin st wo...       0
# 2019-08-21 00:00:32  facebook s libra coin will be a useful and wel...       1
# 2019-08-21 00:00:32  who s firing oracle space x who s hiring sony ...       0
# 2019-08-21 00:00:44  i don t know but anything for randomness since...       0
# ...                                                                ...     ...
# 2019-08-31 23:58:48  iam platform curated tweet report telegram tok...       0
# 2019-08-31 23:59:01  i m guessing leo will always hold due to reput...       0
# 2019-08-31 23:59:17  for if you transactpurposefully transactneedfu...       0
# 2019-08-31 23:59:43  i ve been using coinbase which makes it really...       1
# 2019-08-31 23:59:47  hourly price update usdt bsv bitcoin dead fork...       0
#
# [35563 rows x 2 columns]

# %% [markdown]
# ### Transformers Fine Tuning

# %%
# https://simpletransformers.ai/docs/classification-models/#training-a-classification-model

model_args = ClassificationArgs()
model_args.num_train_epochs = 10
model_args.evaluate_during_training = True
model_args.evaluate_during_training_verbose = True
model_args.use_early_stopping = True
model_args.overwrite_output_dir = True

model_args.best_model_dir = "/gdrive/My Drive/TextAnalytics/models/fineTuned_transformers_sentiment"
#model_args.best_model_dir = r"C:\Users\aine2\Desktop\fineTuned_transformers_sentiment"

# %%
"""
transformers_model = ClassificationModel("bert", "bert-base-uncased", args=model_args, use_cuda=cuda_available)

transformers_model.train_model(df_train_transformers, eval_df=df_validation_transformers)
"""
# Out:
# '\ntransformers_model = ClassificationModel("bert", "bert-base-uncased", args=model_args, use_cuda=cuda_available)\n\ntransformers_model.train_model(df_train_transformers, eval_df=df_validation_transformers)\n'

# %%
#https://huggingface.co/siebert/sentiment-roberta-large-english

transformers_model = ClassificationModel("roberta", "siebert/sentiment-roberta-large-english", args=model_args, use_cuda=cuda_available)

transformers_model.train_model(df_train_transformers_2019, eval_df=df_validation_transformers_2019)

# %%
# import di un modello salvato

transformers_model = ClassificationModel("roberta", "/gdrive/My Drive/TextAnalytics/models/fineTuned_transformers_sentiment", use_cuda=cuda_available)
#transformers_model = ClassificationModel("roberta", r"C:\Users\aine2\Downloads\fineTuned_transformers_sentiment", use_cuda=cuda_available)

# %%
transformers_model.predict(["bitcoin to the moon", "bitcoin flop"])[0]
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# [1, 0]

# %%
transformers_model.eval_model(df_test_transformers_2019)

# %%
df_tweets_polarized_2019["transformers_sentiment"] = transformers_model.predict(list(df_tweets_polarized_2019["text"]))[0]
# Out:
#   0%|          | 0/519002 [00:00<?, ?it/s]
#   0%|          | 0/64876 [00:00<?, ?it/s]

# %%
df_tweets_polarized_2019
# Out:
#                                                                   text  \
# date
# 2019-05-06 02:25:41  wish token giveaway retweet and like this twee...
# 2019-05-06 02:29:30  wish is a decentralized reward platform powere...
# 2019-05-06 03:34:48  new tasks added to contest enter to win huge c...
# 2019-05-06 05:29:29  achain congrats our community member artemiycr...
# 2019-05-06 05:50:31  join on kingcuan our bot will automatically ma...
# ...                                                                ...
# 2019-09-26 23:57:50  on september daps will make its long awaited t...
# 2019-09-26 23:58:06  judge denies release of canadian man accused o...
# 2019-09-26 23:58:30  dutchsunset alexkjanssen alexcobb this message...
# 2019-09-26 23:58:46  pezosaso aaronlevi ltc apompliano changing the...
# 2019-09-26 23:59:57  the future is open source stake amp earn rewar...
#
#                      vader_polarity  vader_sentiment  transformers_sentiment
# date
# 2019-05-06 02:25:41          0.7351                1                       1
# 2019-05-06 02:29:30          0.9451                1                       1
# 2019-05-06 03:34:48          0.8442                1                       1
# 2019-05-06 05:29:29          0.8625                1                       1
# 2019-05-06 05:50:31          0.7506                1                       1
# ...                             ...              ...                     ...
# 2019-09-26 23:57:50          0.7884                1                       1
# 2019-09-26 23:58:06         -0.8316                0                       0
# 2019-09-26 23:58:30         -0.4588                0                       0
# 2019-09-26 23:58:46         -0.5994                0                       0
# 2019-09-26 23:59:57          0.8176                1                       1
#
# [519002 rows x 4 columns]

# %%
df_tweets_polarized_2019.to_csv('/gdrive/My Drive/TextAnalytics/datasets/df_tweets_sentiment_2019.csv')
#df_tweets_polarized_2019.to_csv(r"C:\Users\aine2\Desktop\df_tweets_sentiment_2019.csv")

# %% [markdown]
# # 2021

# %% [markdown]
# ## Datasets

# %%
df_tweets_2021 = pd.read_csv("/gdrive/My Drive/TextAnalytics/datasets/df_tweets_2021.csv")

df_tweets_2021['date'] = pd.to_datetime(df_tweets_2021['date'])
df_tweets_2021 = df_tweets_2021.set_index(['date']).sort_index()

df_tweets_2021
# Out:
#                             user_name  ...               source
# date                                   ...
# 2021-02-05 10:52:04    Iconic Holding  ...      Twitter Web App
# 2021-02-05 10:52:04    Iconic Holding  ...      Twitter Web App
# 2021-02-05 10:52:06    Iconic Holding  ...      Twitter Web App
# 2021-02-05 10:52:07    Iconic Holding  ...      Twitter Web App
# 2021-02-05 10:52:26   Nick Doevendans  ...   Twitter for iPhone
# ...                               ...  ...                  ...
# 2021-07-30 23:59:56  Nitin Dass ∞/21M  ...   Twitter for iPhone
# 2021-07-30 23:59:56      The Last Sat  ...  Twitter for Android
# 2021-07-30 23:59:57          Air アーロン  ...  Twitter for Android
# 2021-07-30 23:59:58      Greg Pearson  ...      Twitter Web App
# 2021-07-30 23:59:59           Tay Sol  ...   Twitter for iPhone
#
# [649001 rows x 9 columns]

# %% [markdown]
# ## Vader Sentiment

# %%
vader = SentimentIntensityAnalyzer()

# %%
df_tweets_2021["vader_polarity"] = df_tweets_2021["text"].apply(lambda text: vader.polarity_scores(str(text)).get('compound'))

# %%
def fromPolarity_toSentiment(polarity):
    if polarity>=0.8:
        return 1
    elif polarity<=-0.2:
        return -1
    else:
        return 0

df_tweets_2021["vader_sentiment"] = df_tweets_2021["vader_polarity"].apply(fromPolarity_toSentiment)

# %%
df_tweets_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 649001 entries, 2021-02-05 10:52:04 to 2021-07-30 23:59:59
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   user_name        649001 non-null  object
#  1   user_created     649001 non-null  object
#  2   user_followers   649001 non-null  float64
#  3   user_friends     649001 non-null  int64
#  4   user_favourites  649001 non-null  int64
#  5   user_verified    649001 non-null  bool
#  6   text             649001 non-null  object
#  7   hashtags         635818 non-null  object
#  8   source           649001 non-null  object
#  9   vader_polarity   649001 non-null  float64
#  10  vader_sentiment  649001 non-null  int64
# dtypes: bool(1), float64(2), int64(3), object(5)
# memory usage: 55.1+ MB

# %%
df_tweets_2021
# Out:
#                             user_name  ... vader_sentiment
# date                                   ...
# 2021-02-05 10:52:04    Iconic Holding  ...               0
# 2021-02-05 10:52:04    Iconic Holding  ...               0
# 2021-02-05 10:52:06    Iconic Holding  ...               0
# 2021-02-05 10:52:07    Iconic Holding  ...               0
# 2021-02-05 10:52:26   Nick Doevendans  ...               0
# ...                               ...  ...             ...
# 2021-07-30 23:59:56  Nitin Dass ∞/21M  ...               0
# 2021-07-30 23:59:56      The Last Sat  ...               0
# 2021-07-30 23:59:57          Air アーロン  ...               0
# 2021-07-30 23:59:58      Greg Pearson  ...               0
# 2021-07-30 23:59:59           Tay Sol  ...              -1
#
# [649001 rows x 11 columns]

# %%
df_tweets_2021["vader_sentiment"].value_counts()
# Out:
#  0    477941
#  1     87419
# -1     83641
# Name: vader_sentiment, dtype: int64

# %%
df_tweets_2021["vader_sentiment"].value_counts(normalize=True)
# Out:
#  0    0.736426
#  1    0.134698
# -1    0.128877
# Name: vader_sentiment, dtype: float64

# %%
df_tweets_2021["vader_sentiment"].value_counts()  # con range [-1; -0.5], [-0.5; 0.5], [0.5, 1]
# Out:
#  0    408680
#  1    207540
# -1     32781
# Name: vader_sentiment, dtype: int64

# %%
df_tweets_polarized_2021 = df_tweets_2021.loc[df_tweets_2021["vader_sentiment"] != 0]

# %%
df_tweets_polarized_2021
# Out:
#                                        user_name  ... vader_sentiment
# date                                              ...
# 2021-02-05 11:14:18                    EmilyNews  ...               0
# 2021-02-05 11:20:58         Trading MarcoDaCosta  ...               0
# 2021-02-05 11:25:28                 Kris Ninakos  ...               0
# 2021-02-05 11:39:20           Emanuel Siddhartha  ...               0
# 2021-02-05 11:44:02  Bitcoin Mate (BTC News App)  ...               0
# ...                                          ...  ...             ...
# 2021-07-30 23:59:16           Alt Center Signals  ...               1
# 2021-07-30 23:59:36                 George Brien  ...               0
# 2021-07-30 23:59:38                       HODL21  ...               0
# 2021-07-30 23:59:50                  David Barge  ...               0
# 2021-07-30 23:59:59                      Tay Sol  ...               0
#
# [171060 rows x 11 columns]

# %%
df_tweets_polarized_2021["vader_sentiment"] = df_tweets_polarized_2021["vader_sentiment"].replace(-1, 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
del df_tweets_2021

# %%
df_tweets_polarized_2021.to_csv('/gdrive/My Drive/TextAnalytics/datasets/df_tweets_polarized_2021.csv')

# %% [markdown]
# ## Transformers Sentiment

# %%
df_tweets_polarized_2021 = pd.read_csv("/gdrive/My Drive/TextAnalytics/datasets/df_tweets_polarized_2021.csv")
#df_tweets_polarized_2021 = pd.read_csv(r"C:\Users\aine2\Downloads\df_tweets_polarized_2021.csv")

df_tweets_polarized_2021['date'] = pd.to_datetime(df_tweets_polarized_2021['date'])
df_tweets_polarized_2021 = df_tweets_polarized_2021.set_index(['date']).sort_index()

df_tweets_polarized_2021
# Out:
#                                        user_name         user_created  \
# date
# 2021-02-05 11:14:18                    EmilyNews  2017-01-16 10:58:53
# 2021-02-05 11:20:58         Trading MarcoDaCosta  2010-03-01 19:35:17
# 2021-02-05 11:25:28                 Kris Ninakos  2018-09-01 12:06:16
# 2021-02-05 11:39:20           Emanuel Siddhartha  2021-02-02 14:01:33
# 2021-02-05 11:44:02  Bitcoin Mate (BTC News App)  2015-03-08 06:31:18
# ...                                          ...                  ...
# 2021-07-30 23:59:16           Alt Center Signals  2020-10-27 15:34:54
# 2021-07-30 23:59:36                 George Brien  2018-07-27 18:41:18
# 2021-07-30 23:59:38                       HODL21  2011-09-23 14:41:38
# 2021-07-30 23:59:50                  David Barge  2009-09-11 20:20:46
# 2021-07-30 23:59:59                      Tay Sol  2016-08-29 09:07:46
#
#                      user_followers  user_friends  user_favourites  \
# date
# 2021-02-05 11:14:18           439.0             1                6
# 2021-02-05 11:20:58          5367.0           927            34484
# 2021-02-05 11:25:28           741.0          1315             3996
# 2021-02-05 11:39:20            15.0            55               59
# 2021-02-05 11:44:02          3312.0          1976              201
# ...                             ...           ...              ...
# 2021-07-30 23:59:16           197.0             2                8
# 2021-07-30 23:59:36         12443.0           140            13523
# 2021-07-30 23:59:38           477.0           914             8322
# 2021-07-30 23:59:50            53.0           138             2584
# 2021-07-30 23:59:59           665.0           184             2234
#
#                      user_verified  \
# date
# 2021-02-05 11:14:18          False
# 2021-02-05 11:20:58          False
# 2021-02-05 11:25:28          False
# 2021-02-05 11:39:20          False
# 2021-02-05 11:44:02          False
# ...                            ...
# 2021-07-30 23:59:16          False
# 2021-07-30 23:59:36          False
# 2021-07-30 23:59:38          False
# 2021-07-30 23:59:50          False
# 2021-07-30 23:59:59          False
#
#                                                                   text  \
# date
# 2021-02-05 11:14:18  warning powerearn outside project fast scam si...
# 2021-02-05 11:20:58  twitter ceo jack dorsey has fired up a full bi...
# 2021-02-05 11:25:28  a possible big move for btc bitcoin is coming ...
# 2021-02-05 11:39:20  no vcs no ico no unlimited supply no pump and ...
# 2021-02-05 11:44:02  bitcoin s wild ride renews worries about its m...
# ...                                                                ...
# 2021-07-30 23:59:16  binance futures srm usdt all take profit targe...
# 2021-07-30 23:59:36  bitcoin at k will hit k soon hodl yours don t ...
# 2021-07-30 23:59:38  i m actually one of the few people i know who ...
# 2021-07-30 23:59:50                   bitcoin cruising by k no problem
# 2021-07-30 23:59:59  clear manipulation by whales in the market to ...
#
#                                                               hashtags  \
# date
# 2021-02-05 11:14:18  ['EmilyNews', 'invest', 'HYIPs', 'bitcoin', 'c...
# 2021-02-05 11:20:58            ['Twitter', 'Dorsey', 'Bitcoin', 'BTC']
# 2021-02-05 11:25:28                                 ['BTC', 'BITCOIN']
# 2021-02-05 11:39:20                ['znn', 'aliens', 'BTC', 'Bitcoin']
# 2021-02-05 11:44:02                                                NaN
# ...                                                                ...
# 2021-07-30 23:59:16  ['SRM', 'Signals', 'CryptoSignals', 'Crypto', ...
# 2021-07-30 23:59:36                                        ['Bitcoin']
# 2021-07-30 23:59:38                                        ['bitcoin']
# 2021-07-30 23:59:50                                        ['Bitcoin']
# 2021-07-30 23:59:59          ['cryptocurrency', 'bitcoin', 'safemoon']
#
#                                   source  vader_polarity  vader_sentiment
# date
# 2021-02-05 11:14:18                IFTTT         -0.7269                0
# 2021-02-05 11:20:58   Twitter for iPhone         -0.5574                0
# 2021-02-05 11:25:28  Twitter for Android         -0.2023                0
# 2021-02-05 11:39:20      Twitter Web App         -0.8910                0
# 2021-02-05 11:44:02           Twibble.io         -0.4215                0
# ...                                  ...             ...              ...
# 2021-07-30 23:59:16                IFTTT          0.8271                1
# 2021-07-30 23:59:36   Twitter for iPhone         -0.5106                0
# 2021-07-30 23:59:38   Twitter for iPhone         -0.2960                0
# 2021-07-30 23:59:50  Twitter for Android         -0.5994                0
# 2021-07-30 23:59:59   Twitter for iPhone         -0.4144                0
#
# [171060 rows x 11 columns]

# %%
# import di un modello salvato

transformers_model = ClassificationModel("roberta", "/gdrive/My Drive/TextAnalytics/models/fineTuned_transformers_sentiment", use_cuda=cuda_available)
#transformers_model = ClassificationModel("roberta", r"C:\Users\aine2\Downloads\fineTuned_transformers_sentiment", use_cuda=cuda_available)

# %%
df_tweets_polarized_2021["transformers_sentiment"] = transformers_model.predict(list(df_tweets_polarized_2021["text"]))[0]
# Out:
#   0%|          | 0/171060 [00:00<?, ?it/s]
#   0%|          | 0/21383 [00:00<?, ?it/s]

# %%
df_tweets_polarized_2021
# Out:
#                                        user_name         user_created  \
# date
# 2021-02-05 11:14:18                    EmilyNews  2017-01-16 10:58:53
# 2021-02-05 11:20:58         Trading MarcoDaCosta  2010-03-01 19:35:17
# 2021-02-05 11:25:28                 Kris Ninakos  2018-09-01 12:06:16
# 2021-02-05 11:39:20           Emanuel Siddhartha  2021-02-02 14:01:33
# 2021-02-05 11:44:02  Bitcoin Mate (BTC News App)  2015-03-08 06:31:18
# ...                                          ...                  ...
# 2021-07-30 23:59:16           Alt Center Signals  2020-10-27 15:34:54
# 2021-07-30 23:59:36                 George Brien  2018-07-27 18:41:18
# 2021-07-30 23:59:38                       HODL21  2011-09-23 14:41:38
# 2021-07-30 23:59:50                  David Barge  2009-09-11 20:20:46
# 2021-07-30 23:59:59                      Tay Sol  2016-08-29 09:07:46
#
#                      user_followers  user_friends  user_favourites  \
# date
# 2021-02-05 11:14:18           439.0             1                6
# 2021-02-05 11:20:58          5367.0           927            34484
# 2021-02-05 11:25:28           741.0          1315             3996
# 2021-02-05 11:39:20            15.0            55               59
# 2021-02-05 11:44:02          3312.0          1976              201
# ...                             ...           ...              ...
# 2021-07-30 23:59:16           197.0             2                8
# 2021-07-30 23:59:36         12443.0           140            13523
# 2021-07-30 23:59:38           477.0           914             8322
# 2021-07-30 23:59:50            53.0           138             2584
# 2021-07-30 23:59:59           665.0           184             2234
#
#                      user_verified  \
# date
# 2021-02-05 11:14:18          False
# 2021-02-05 11:20:58          False
# 2021-02-05 11:25:28          False
# 2021-02-05 11:39:20          False
# 2021-02-05 11:44:02          False
# ...                            ...
# 2021-07-30 23:59:16          False
# 2021-07-30 23:59:36          False
# 2021-07-30 23:59:38          False
# 2021-07-30 23:59:50          False
# 2021-07-30 23:59:59          False
#
#                                                                   text  \
# date
# 2021-02-05 11:14:18  warning powerearn outside project fast scam si...
# 2021-02-05 11:20:58  twitter ceo jack dorsey has fired up a full bi...
# 2021-02-05 11:25:28  a possible big move for btc bitcoin is coming ...
# 2021-02-05 11:39:20  no vcs no ico no unlimited supply no pump and ...
# 2021-02-05 11:44:02  bitcoin s wild ride renews worries about its m...
# ...                                                                ...
# 2021-07-30 23:59:16  binance futures srm usdt all take profit targe...
# 2021-07-30 23:59:36  bitcoin at k will hit k soon hodl yours don t ...
# 2021-07-30 23:59:38  i m actually one of the few people i know who ...
# 2021-07-30 23:59:50                   bitcoin cruising by k no problem
# 2021-07-30 23:59:59  clear manipulation by whales in the market to ...
#
#                                                               hashtags  \
# date
# 2021-02-05 11:14:18  ['EmilyNews', 'invest', 'HYIPs', 'bitcoin', 'c...
# 2021-02-05 11:20:58            ['Twitter', 'Dorsey', 'Bitcoin', 'BTC']
# 2021-02-05 11:25:28                                 ['BTC', 'BITCOIN']
# 2021-02-05 11:39:20                ['znn', 'aliens', 'BTC', 'Bitcoin']
# 2021-02-05 11:44:02                                                NaN
# ...                                                                ...
# 2021-07-30 23:59:16  ['SRM', 'Signals', 'CryptoSignals', 'Crypto', ...
# 2021-07-30 23:59:36                                        ['Bitcoin']
# 2021-07-30 23:59:38                                        ['bitcoin']
# 2021-07-30 23:59:50                                        ['Bitcoin']
# 2021-07-30 23:59:59          ['cryptocurrency', 'bitcoin', 'safemoon']
#
#                                   source  vader_polarity  vader_sentiment  \
# date
# 2021-02-05 11:14:18                IFTTT         -0.7269                0
# 2021-02-05 11:20:58   Twitter for iPhone         -0.5574                0
# 2021-02-05 11:25:28  Twitter for Android         -0.2023                0
# 2021-02-05 11:39:20      Twitter Web App         -0.8910                0
# 2021-02-05 11:44:02           Twibble.io         -0.4215                0
# ...                                  ...             ...              ...
# 2021-07-30 23:59:16                IFTTT          0.8271                1
# 2021-07-30 23:59:36   Twitter for iPhone         -0.5106                0
# 2021-07-30 23:59:38   Twitter for iPhone         -0.2960                0
# 2021-07-30 23:59:50  Twitter for Android         -0.5994                0
# 2021-07-30 23:59:59   Twitter for iPhone         -0.4144                0
#
#                      transformers_sentiment
# date
# 2021-02-05 11:14:18                       0
# 2021-02-05 11:20:58                       1
# 2021-02-05 11:25:28                       1
# 2021-02-05 11:39:20                       1
# 2021-02-05 11:44:02                       0
# ...                                     ...
# 2021-07-30 23:59:16                       1
# 2021-07-30 23:59:36                       0
# 2021-07-30 23:59:38                       1
# 2021-07-30 23:59:50                       1
# 2021-07-30 23:59:59                       0
#
# [171060 rows x 12 columns]

# %%
df_tweets_polarized_2021.to_csv('/gdrive/My Drive/TextAnalytics/datasets/df_tweets_sentiment_2021.csv')
#df_tweets_polarized_2021.to_csv(r"C:\Users\aine2\Desktop\df_tweets_sentiment_2021.csv")
