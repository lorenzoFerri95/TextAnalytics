# %%
import math
import random
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from datetime import datetime
import time
from sklearn.inspection import permutation_importance

plt.style.use('classic')
# %matplotlib inline
sns.set()

from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ### Functions

# %%
def tweets_cleaner(text):

    text = ' '.join(text.split('.'))
    text = re.sub('\/',' ',text)
    text = text.strip('\'"')
    text = re.sub(r'@([^\s]+)',r'\1',text)
    text = re.sub(r'\\',' ',text)
    text = text.lower()
    text = re.sub('[\s]+', ' ', text)
    text = re.sub(r'#([^\s]+)', r'\1', text)
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))',' ',text)
    text = re.sub(r'((http)\S+)','',text)
    text = re.sub(r'\s+', ' ', re.sub('[^A-Za-z]', ' ', text.strip().lower())).strip()
    text = re.sub(r'\W+', ' ', text.strip().lower()).strip()

    return text

# %%
def test_binary_clf(clf, X_test, y_test):
    
    y_pred = clf.predict(X_test)
    
    print('Accuracy: %s' % accuracy_score(y_test, y_pred), end='\n\n')
    print('F1-score: %s' % f1_score(y_test, y_pred, average=None), end='\n\n')
    print('Weighted Average F1-score: %s' % f1_score(y_test, y_pred, average='weighted'), end='\n\n')
    print(classification_report(y_test, y_pred), end='\n\n')

    cf_matrix = confusion_matrix(y_test, y_pred)
    categories = ['Negative', 'Positive']
    group_names = ['True Negative', 'False Positive', 'False Negative', 'True Positive']

    group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten() / np.sum(cf_matrix)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names, group_percentages)]
    labels = np.asarray(labels).reshape(2,2)

    sns.heatmap(cf_matrix, annot = labels, cmap = 'Blues', fmt = '', xticklabels=categories, yticklabels=categories)
    plt.xlabel("Predicted values", fontdict = {'size':14}, labelpad = 10)
    plt.ylabel("Actual values", fontdict = {'size':14}, labelpad = 10)
    plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)
    plt.show()
    
    print("\n")

    y_score = clf.predict_proba(X_test)
    fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, color='darkorange', lw=2, label='$AUC$ = %.3f' % (roc_auc))

    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=16)
    plt.ylabel('True Positive Rate', fontsize=16)
    plt.title('ROC curve', fontsize=16)
    plt.legend(loc="lower right", fontsize=14, frameon=False)
    plt.tick_params(axis='both', which='major', labelsize=16)
    plt.show()

    return y_pred


def feature_importance(estimator, X_train, y_train):

    nbr_features = X_train.shape[1]

    try:
        tree_feature_importances = estimator.feature_importances_
        sorted_idx = tree_feature_importances.argsort()[-nbr_features:]

        plt.barh(range(nbr_features), tree_feature_importances[sorted_idx])
        plt.yticks(range(nbr_features), X_train.columns[sorted_idx])
        plt.title("Feature Importances on Training Set")
        plt.show()

    except:
        perm_importance = permutation_importance(estimator, X_train, y_train, n_repeats=10, random_state=100, n_jobs=2)

        sorted_idx = perm_importance.importances_mean.argsort()[-nbr_features:]

        plt.boxplot(perm_importance.importances[sorted_idx].T, vert=False, labels=X_train.columns[sorted_idx])
        plt.title("Permutation Importances on Training Set")
        plt.tight_layout()
        plt.show()


def test_reg(reg, X_test, y_test):

    y_pred = reg.predict(X_test)
    
    print('R2: %.3f' % r2_score(y_test, y_pred))
    print('MSE: %.3f' % mean_squared_error(y_test, y_pred))
    print('MAE: %.3f' % mean_absolute_error(y_test, y_pred))
    print('RMSE: %.3f' % math.sqrt(mean_squared_error(y_test, y_pred)))

    return y_pred

# %% [markdown]
# # Dataset

# %%
df_predictions_2019 = pd.read_csv("/gdrive/My Drive/TextAnalytics/datasets/df_predictions_2019.csv")

df_predictions_2019['date'] = pd.to_datetime(df_predictions_2019['date'])
df_predictions_2019 = df_predictions_2019.set_index(['date']).sort_index()

df_predictions_2019
# Out:
#                      tweets_volume  ...  volatility_next2min
# date                                ...
# 2019-05-06 05:29:00              1  ...             0.067637
# 2019-05-06 07:26:00              2  ...             0.073179
# 2019-05-06 07:39:00              1  ...             0.072450
# 2019-05-06 08:31:00              2  ...             0.072788
# 2019-05-06 08:48:00              1  ...             0.073415
# ...                            ...  ...                  ...
# 2019-09-26 23:41:00              2  ...             0.124025
# 2019-09-26 23:42:00              1  ...             0.124029
# 2019-09-26 23:43:00              1  ...             0.123747
# 2019-09-26 23:44:00              3  ...             0.123861
# 2019-09-26 23:45:00              4  ...             0.124144
#
# [127563 rows x 11 columns]

# %% [markdown]
# # Up_Down_next2min Prediction

# %%
import pickle

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression

from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM

# %% [markdown]
# ## Train Test Split

# %%
train_test_split_date = "2019-09-05 00:00:00"
X_cols = ["tweets_volume", "median_polarity", "vader_sentiment_mode", "transformers_sentiment_mode", "returns", "volatility", "up_down"]
y_col = "up_down_next2min"

X_train = df_predictions_2019[X_cols].loc[df_predictions_2019.index < train_test_split_date].copy()
y_train = df_predictions_2019[y_col].loc[df_predictions_2019.index < train_test_split_date].copy()
X_test = df_predictions_2019[X_cols].loc[df_predictions_2019.index >= train_test_split_date].copy()
y_test = df_predictions_2019[y_col].loc[df_predictions_2019.index >= train_test_split_date].copy()

# %%
X_train
# Out:
#                      tweets_volume  median_polarity  ...  volatility  up_down
# date                                                 ...
# 2019-05-06 05:29:00              1          0.86250  ...    0.113277        1
# 2019-05-06 07:26:00              2          0.75005  ...    0.067993       -1
# 2019-05-06 07:39:00              1          0.72690  ...    0.067637       -1
# 2019-05-06 08:31:00              2          0.82890  ...    0.073179        1
# 2019-05-06 08:48:00              1          0.84420  ...    0.072450       -1
# ...                            ...              ...  ...         ...      ...
# 2019-09-04 23:53:00              1          0.70030  ...    0.128238        1
# 2019-09-04 23:54:00              5          0.76500  ...    0.128577       -1
# 2019-09-04 23:56:00              3          0.70030  ...    0.128381       -1
# 2019-09-04 23:57:00              1          0.90620  ...    0.128347       -1
# 2019-09-04 23:58:00              1         -0.38750  ...    0.128545       -1
#
# [107098 rows x 7 columns]

# %%
y_train.value_counts(normalize=True)
# Out:
#  1.0    0.505154
# -1.0    0.494846
# Name: up_down_next2min, dtype: float64

# %%
X_test
# Out:
#                      tweets_volume  median_polarity  ...  volatility  up_down
# date                                                 ...
# 2019-09-05 00:00:00              3          0.77830  ...    0.128536        1
# 2019-09-05 00:02:00              4         -0.46430  ...    0.129148       -1
# 2019-09-05 00:03:00              1         -0.36120  ...    0.129094       -1
# 2019-09-05 00:04:00              3         -0.34000  ...    0.129310       -1
# 2019-09-05 00:07:00              1         -0.31820  ...    0.129342       -1
# ...                            ...              ...  ...         ...      ...
# 2019-09-26 23:41:00              2          0.18860  ...    0.124099       -1
# 2019-09-26 23:42:00              1         -0.40190  ...    0.124198       -1
# 2019-09-26 23:43:00              1          0.83160  ...    0.124025       -1
# 2019-09-26 23:44:00              3          0.70030  ...    0.124029       -1
# 2019-09-26 23:45:00              4          0.08805  ...    0.123747        1
#
# [20465 rows x 7 columns]

# %%
y_test.value_counts(normalize=True)
# Out:
#  1.0    0.508478
# -1.0    0.491522
# Name: up_down_next2min, dtype: float64

# %% [markdown]
# ### Random Forest

# %%
pipeline = Pipeline([
                     #('scaler', StandardScaler()),
                     #('pca', PCA()),
                     ('clf', RandomForestClassifier())  # learning classifier
                     ])

# %%
r_param_grid = [
                #{'pca__n_components': list(range(4,8))},
                {'clf__max_depth': list(range(5, 20))}
                ]


optr_search = RandomizedSearchCV(pipeline, r_param_grid, cv=5, n_iter=10, n_jobs=4, verbose=True).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:  8.6min finished

# %%
optr_search.best_params_

# %%
optr_search.cv_results_

# %%
best_pipe = optr_search.best_estimator_

# %%
best_pipe
# Out:
# Pipeline(memory=None,
#          steps=[('clf',
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=8, max_features='auto',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
best_pipe.predict(X_test)
# Out:
# array([-1.,  1.,  1., ..., -1., -1.,  1.])

# %%
with open('/gdrive/My Drive/TextAnalytics/models/fitted_randomForest', 'wb') as f:
    pickle.dump(best_pipe, f)

# %%
"""
with open("/gdrive/My Drive/TextAnalytics/models/fitted_randomForest", 'rb') as f:
    best_pipe = pickle.load(f)
"""

# %%
y_pred = test_binary_clf(best_pipe, X_test, y_test)
# Out:
# Accuracy: 0.5702350124590805
#
# F1-score: [0.56072713 0.57934003]
#
# Weighted Average F1-score: 0.5701904513528548
#
#               precision    recall  f1-score   support
#
#         -1.0       0.56      0.56      0.56     10061
#          1.0       0.58      0.58      0.58     10406
#
#     accuracy                           0.57     20467
#    macro avg       0.57      0.57      0.57     20467
# weighted avg       0.57      0.57      0.57     20467

# %%
feature_importance(best_pipe["clf"], X_train, y_train)

# %% [markdown]
# #### Prediction without Text related features

# %%
train_test_split_date = "2019-09-05 00:00:00"
X_cols = ["returns", "volatility", "up_down"]
y_col = "up_down_next2min"

X_train = df_predictions_2019[X_cols].loc[df_predictions_2019.index < train_test_split_date].copy()
y_train = df_predictions_2019[y_col].loc[df_predictions_2019.index < train_test_split_date].copy()
X_test = df_predictions_2019[X_cols].loc[df_predictions_2019.index >= train_test_split_date].copy()
y_test = df_predictions_2019[y_col].loc[df_predictions_2019.index >= train_test_split_date].copy()

# %%
clf = RandomForestClassifier(max_depth=optr_search.best_params_["clf__max_depth"]).fit(X_train, y_train)

# %%
test_binary_clf(clf, X_test, y_test)
# Out:
# Accuracy: 0.5697952802071627
#
# F1-score: [0.56627752 0.57325643]
#
# Weighted Average F1-score: 0.5698257982360926
#
#               precision    recall  f1-score   support
#
#         -1.0       0.56      0.57      0.57     10061
#          1.0       0.58      0.57      0.57     10406
#
#     accuracy                           0.57     20467
#    macro avg       0.57      0.57      0.57     20467
# weighted avg       0.57      0.57      0.57     20467
# array([-1.,  1.,  1., ..., -1., -1.,  1.])

# %%
feature_importance(clf, X_train, y_train)

# %% [markdown]
# #### Prediction with only Text related features

# %%
train_test_split_date = "2019-09-05 00:00:00"
X_cols = ["tweets_volume", "median_polarity", "vader_sentiment_mode", "transformers_sentiment_mode"]
y_col = "up_down_next2min"

X_train = df_predictions_2019[X_cols].loc[df_predictions_2019.index < train_test_split_date].copy()
y_train = df_predictions_2019[y_col].loc[df_predictions_2019.index < train_test_split_date].copy()
X_test = df_predictions_2019[X_cols].loc[df_predictions_2019.index >= train_test_split_date].copy()
y_test = df_predictions_2019[y_col].loc[df_predictions_2019.index >= train_test_split_date].copy()

# %%
clf = RandomForestClassifier(max_depth=optr_search.best_params_["clf__max_depth"]).fit(X_train, y_train)

# %%
test_binary_clf(clf, X_test, y_test)
# Out:
# Accuracy: 0.5035911467239947
#
# F1-score: [0.31573276 0.61051905]
#
# Weighted Average F1-score: 0.4656104237746414
#
#               precision    recall  f1-score   support
#
#         -1.0       0.49      0.23      0.32     10061
#          1.0       0.51      0.77      0.61     10406
#
#     accuracy                           0.50     20467
#    macro avg       0.50      0.50      0.46     20467
# weighted avg       0.50      0.50      0.47     20467
# array([-1.,  1.,  1., ...,  1.,  1.,  1.])

# %%
feature_importance(clf, X_train, y_train)

# %% [markdown]
# # Returns_next2min Prediction

# %% [markdown]
# ## Train Test Split

# %%
train_test_split_date = "2019-09-05 00:00:00"
X_cols = ["tweets_volume", "median_polarity", "vader_sentiment_mode", "transformers_sentiment_mode", "returns", "volatility", "up_down"]
y_col = "returns_next2min"

X_train = df_predictions_2019[X_cols].loc[df_predictions_2019.index < train_test_split_date].copy()
y_train = df_predictions_2019[y_col].loc[df_predictions_2019.index < train_test_split_date].copy()
X_test = df_predictions_2019[X_cols].loc[df_predictions_2019.index >= train_test_split_date].copy()
y_test = df_predictions_2019[y_col].loc[df_predictions_2019.index >= train_test_split_date].copy()

# %%
y_train
# Out:
# date
# 2019-05-06 05:29:00   -0.033911
# 2019-05-06 07:26:00    0.051701
# 2019-05-06 07:39:00   -0.040469
# 2019-05-06 08:31:00   -0.000713
# 2019-05-06 08:48:00   -0.044076
#                          ...
# 2019-09-04 23:53:00   -0.016805
# 2019-09-04 23:54:00   -0.025779
# 2019-09-04 23:56:00   -0.111596
# 2019-09-04 23:57:00    0.025502
# 2019-09-04 23:58:00   -0.215456
# Name: returns_next2min, Length: 107098, dtype: float64

# %% [markdown]
# ### Linear Regression

# %%
reg = LinearRegression().fit(X_train, y_train)

predictions = test_reg(reg, X_test, y_test)
# Out:
# R2: -0.000
# MSE: 0.013
# MAE: 0.068
# RMSE: 0.115

# %% [markdown]
# # Volatility_next2min Prediction

# %% [markdown]
# ## Train Test Split

# %%
train_test_split_date = "2019-09-05 00:00:00"
X_cols = ["tweets_volume", "median_polarity", "vader_sentiment_mode", "transformers_sentiment_mode", "returns", "volatility", "up_down"]
y_col = "volatility_next2min"

X_train = df_predictions_2019[X_cols].loc[df_predictions_2019.index < train_test_split_date].copy()
y_train = df_predictions_2019[y_col].loc[df_predictions_2019.index < train_test_split_date].copy()
X_test = df_predictions_2019[X_cols].loc[df_predictions_2019.index >= train_test_split_date].copy()
y_test = df_predictions_2019[y_col].loc[df_predictions_2019.index >= train_test_split_date].copy()

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X_train, y_train)

predictions = test_reg(reg, X_test, y_test)
# Out:
# R2: 0.998
# MSE: 0.000
# MAE: 0.001
# RMSE: 0.003

# %% [markdown]
# ### LSTM

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
# reshape input to be [samples, time steps, features]

X_train = np.reshape(np.array(X_train), (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(np.array(X_test), (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(10, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train,
          batch_size=1024,
          epochs=100,
          validation_split=0.1)
# Out:
# Epoch 1/100
# 95/95 [==============================] - 3s 8ms/step - loss: 0.6423 - accuracy: 0.0000e+00 - val_loss: 0.5509 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.5332 - accuracy: 0.0000e+00 - val_loss: 0.4211 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4581 - accuracy: 0.0000e+00 - val_loss: 0.3583 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4269 - accuracy: 0.0000e+00 - val_loss: 0.3377 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4168 - accuracy: 0.0000e+00 - val_loss: 0.3324 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4139 - accuracy: 0.0000e+00 - val_loss: 0.3311 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4126 - accuracy: 0.0000e+00 - val_loss: 0.3306 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4118 - accuracy: 0.0000e+00 - val_loss: 0.3304 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4112 - accuracy: 0.0000e+00 - val_loss: 0.3302 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4107 - accuracy: 0.0000e+00 - val_loss: 0.3300 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4102 - accuracy: 0.0000e+00 - val_loss: 0.3299 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4098 - accuracy: 0.0000e+00 - val_loss: 0.3298 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4096 - accuracy: 0.0000e+00 - val_loss: 0.3297 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4094 - accuracy: 0.0000e+00 - val_loss: 0.3297 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4092 - accuracy: 0.0000e+00 - val_loss: 0.3297 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4091 - accuracy: 0.0000e+00 - val_loss: 0.3296 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4089 - accuracy: 0.0000e+00 - val_loss: 0.3296 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4088 - accuracy: 0.0000e+00 - val_loss: 0.3296 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4087 - accuracy: 0.0000e+00 - val_loss: 0.3296 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4087 - accuracy: 0.0000e+00 - val_loss: 0.3296 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4086 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4085 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4085 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4084 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4084 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4083 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4082 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4083 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4082 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4082 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4082 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4081 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4080 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4080 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4079 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4079 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4079 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4079 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4078 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4077 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4076 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4077 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4076 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4075 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 52/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4075 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4075 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 54/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4075 - accuracy: 0.0000e+00 - val_loss: 0.3295 - val_accuracy: 0.0000e+00
# Epoch 55/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4075 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 56/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4075 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4075 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4074 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4074 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4074 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4074 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 62/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4073 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4072 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 64/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4073 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4072 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4072 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4072 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 70/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 72/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 73/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4070 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4070 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 75/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4070 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4069 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 77/100
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4070 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 78/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4069 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 79/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4069 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 80/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4068 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4068 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4068 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4068 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4068 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4068 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4067 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4067 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4067 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4067 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4067 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4065 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4065 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4065 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00

# %%
predictions = test_reg(model, X_test, y_test)
# Out:
# R2: 0.381
# MSE: 0.002
# MAE: 0.042
# RMSE: 0.045
